# %% [markdown]
# 1. Find the sum of all elements in a list.

# %%
l = [1,2,3]
sum(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-0b4621022cc6> in <module>
#       1 l = [1,2,3]
# ----> 2 sum(l)
#
# TypeError: 'int' object is not callable
